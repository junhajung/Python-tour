# %%
import requests
from bs4 import BeautifulSoup
import pymysql
from  selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time as time
import getpass
import urllib.request
import random
import re
import csv
 
from time import sleep
 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('csv/충남2.csv')

# df.rename(columns = df.iloc[0], inplace=True)
df = df.drop(['like'], axis=1)
df = df.dropna(axis=0)
df = df.drop_duplicates(['place'])
df = df.drop_duplicates(['tags'])

df
# # df['place'] = df['place'].str.replace(pat=r'[" "]', repl=r'', regex=True)
# df1 = df['place'] == '아그로랜드 태신목장'

# df2 = df1 == True
# # df2
cnt1 = 0
cnt2 = 0
cnt3 = 0
cnt4 = 0
cnt5 = 0
cnt6 = 0
cnt7 = 0
cnt8 = 0
cnt9 = 0
cnt10 = 0
cnt11 = 0
cnt12 = 0
cnt13 = 0
cnt14 = 0
cnt15 = 0
# 서산 = 공주 > 태안 > 당진 > 예산 > 아산 = 부여 
df3 = df[df['tags'].str.contains('서산')]
# df3
df2 = []
for i in df['tags']:
    if "#천안" in i: #18
        df2.append(i)
#         print(df2)
        cnt3 += 1
    elif "#예산" in i: #9
        cnt4 += 1
    elif "#공주" in i: #18
        cnt5 += 1
    elif "#아산" in i: # 8
        cnt7 += 1
    elif "#태안" in i: # 13
        cnt9 += 1
    elif "#부여" in i: # 8
        cnt11 += 1
    elif "#당진" in i: # 11
        cnt12 += 1
        
df
# prin(cn31)
# print(cnt2)
print(cnt3)
print(cnt4)
print(cnt5)
# print(cnt6)
print(cnt7)
# print(cnt8)
print(cnt9)
# print(cnt10)
print(cnt11)
print(cnt12)
# print(cnt13)
# print(cnt14)
# print(cnt15)

    
# s = df.groupby('place')['place'].transform('size')
# print(s)
# #     if(i == '아그로랜드 태신목장'):
# #         cnt += 1
    

# print(cnt)
# df = df.drop(df.index[0])
# Out:
#      Unnamed: 0                                            content  \
# 0             0  스토리 올렸더니 문의 폭주한 장소❤️어딘지 알려드릴게요!!저희가 감사하게도 첫 손님...
# 1             1  사랑나무💛⠀동화같은 나무 아래에서예쁜 노을이 펼쳐지던 곳🌈⠀하트 반쪽짜리 나무를 찍...
# 3             3         •낮과 밤의 어디쯤•••••📸#EOSR + #RF2870F2📍#삽교호놀이동산
# 4             4  ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀너의 입장에서 생각해 볼게,그럼 열리지 않을까-⠀⠀⠀⠀⠀⠀...
# 5             5  잠깐 수국나라 다녀왔습니다제주아니고 거제도 아니고 가까운 공주입니다#공주 #유구색동...
# ..          ...                                                ...
# 959         959           #바른커피람그늘에서 피크닉 딱이죠??피크닉 문의는 카카오톡으로 부탁드려요
# 962         962  🌼#샤스타데이지 볼 수 있는 2곳 인생사진.zip🌼올해 #데이지 에 진심 이신 분들...
# 969         969                        🍯이 뚝뚝...💛#소띠아기 #아빠와딸 #아기랑여행
# 986         986  갯벌🦀...........#서천송림갯벌체험 #갯벌체험 #송림갯벌체험장 #일상 #육아...
# 989         989  2021.05.30_3번째여행_당진_왜목마을해수욕장_300일💓300일 기념으로 내 ...
#
#            data       place                                               tags
# 0    2021-05-30       선셋파머스             ['#선셋파머스', '#금산숙소', '#금산펜션', '#에어비엔비']
# ...

# %%
arr = {"서산","공주","태안","당진","예산"}
arr1 = ["간월암","해미읍성","개심사"]
arr2 = ["공주한옥마을","공산성","유구색동수국공원"]
arr3 = ["꽃지해수욕장","토굴새우젓단지","안면도자연휴양림"]
arr4 = ["아그로랜드 태신목장","마섬포구","왜목마을"]
arr5 = ["추사고택","수덕사","덕산온천"]
for i in range(0,4,1):
    data = [
        {"name":arr},
        {"content":arr + str(i)}
    ]

print(data)
# collection.insert_many(data)

df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-5724d52a1d8a> in <module>
#       8     data = [
#       9         {"name":arr},
# ---> 10         {"content":arr + str(i)}
#      11     ]
#      12
#
# TypeError: unsupported operand type(s) for +: 'set' and 'str'

# %%
import requests
import hdfs 
import json
import bs4
import requests
import io
import bson
import time
from selenium import webdriver  # pip install selenium
import bs4 # pip install bs4
import time
import urllib.request as REQ  #서버 요청
import pymongo
import urllib.request
from PIL import Image

img = "https://mblogthumb-phinf.pstatic.net/MjAxNzA5MjJfMjI0/MDAxNTA2MDY2NTk5MTcx.6px0DEy7RxgY67x4ZkX345qQNyy2yq_kDME4Nwb1Jn8g.-xgLNyLJtRNoLWHOeKNzQ_KT6jC_bp3aC28ISWyffD8g.JPEG.wawaw0116/20170813_123918.jpg?type=w2"
img1 = "https://mblogthumb-phinf.pstatic.net/MjAxODExMjZfMTAg/MDAxNTQzMjIwODQ3ODk5.G_dH2Tzr0RdLjqiQVD-vICw1NMU-OchODmkF-PMdPIog.AOsO4zsBQkCiR6mGtrZ4OufZmCFqK9iNEPrjrKZ_3Zog.JPEG.start1q/8h181121.JPG?type=w800"
img2 = "https://mblogthumb-phinf.pstatic.net/MjAxOTA4MTdfMTIg/MDAxNTY2MDAyNzA3MDAy.ZHA-80KKSgeaS-4cu9NHyJIa7j4dw0CMtVUXEW3RHZ0g.wY5dCY81WLTSX7BABADAA6S2bSFRX9Kjw3araP4eSXEg.JPEG.lhj6332/KakaoTalk_20190817_094107568.jpg?type=w800"

img3 = "https://cdn.imweb.me/thumbnail/20180522/5b041883732c6.jpg"
img4 = "https://lh3.googleusercontent.com/proxy/XpYfaEdjqCz-G5i2400iOO3wtSzi29TpTya-QokmYAIqPbpDhMpBZUQWjFTF5WdaKpPTmohILhkbR2kFXtHqLkkAArUkMT575ounp_bSeTp7hR6K3NQXMg"
img5 = "https://mblogthumb-phinf.pstatic.net/20160816_239/fastcheonan_1471314449426r0qVw_JPEG/14002555_573108766229118_1302075884_o.jpg?type=w800"

img6 = "https://www.brcn.go.kr/prog/attraction/tour/sub01_08/attractionImage_down.do?attractionCode=128"
img7 = "https://t1.daumcdn.net/cfile/tistory/2157214458BA6E8431"

img8 = "https://mblogthumb-phinf.pstatic.net/MjAxODA5MjdfNjcg/MDAxNTM4MDIxOTk3OTg2.23IeUlrTYcD6KDkYyXD0K7S-jNPcE47ei2H7yhJ5Y-Qg.mgBFLtoKgxR7NvIK8Xxy56ANLwvDapJZzUyt4hrVXkMg.JPEG.djasla771/20180926_162811.jpg?type=w800"
img9 = "https://mblogthumb-phinf.pstatic.net/MjAxODA1MjVfMTQy/MDAxNTI3MjIyMDU1NTky.iF12BZ5N8CBuoGGe85ElCB0BIKcHXgBuLgRVfnMM69og.mMCZg0okxGWDob2GB2sJe9twWHJeP4Dp_-BKiun4PmQg.JPEG.cjyong0502/IMG_1448.jpg?type=w800"
img10 = "https://lh3.googleusercontent.com/proxy/g1PGQD3fxGK_sfrgiXxJFDCoj5JmVlUebYi44a_uLpssZ_f3F_b2NpYQaUZ2BdptAOO4p-kB0QhVl4id91AA5ctARC7erycS_PkJrWfud8bOvX06n9Jj4PZIID6YQV2yYHCyN0FWULvKM6HoNDh_eFyK15syI5Gy3Ar5pbsuzY73XgY959c4s_g_epBdHOjk"
img11 = "https://static.leisureq.io/1200/production-gajago-deal-images/d501acfe-28a8-46d3-b266-1ff237578843.JPG"
img12 = "https://pds.joins.com//news/component/htmlphoto_mmdata/201710/17/ad665b6e-c389-4bcd-b5e1-f400eee37159.jpg"
img13 = "https://lh3.googleusercontent.com/proxy/7VOkzMASmOMHjUaNcen82eNCzUijIIE9OjETbTRZo9Fjr3Z4UUORCjtRjqRrTrnY2Rwhg4SWFH8fvd7OpbomQI_iksfj1pORQzX3z4jUYt7r6gE2CvD5KQXY"
img14 = "https://t1.daumcdn.net/cfile/tistory/99BAAF3C5D970A821C"







urllib.request.urlretrieve(img,  "대둔산짚핑.jpg")
urllib.request.urlretrieve(img1,  "대천짚라인.jpg")
urllib.request.urlretrieve(img2, "영인산자연휴양림.jpg")

urllib.request.urlretrieve(img3,  "강경수상레저.jpg")
urllib.request.urlretrieve(img4,  "해양레저체험교실.jpg")
urllib.request.urlretrieve(img5,  "천안케이블워터파크.jpg")
urllib.request.urlretrieve(img6,  "대천패러글라이딩.jpg")
urllib.request.urlretrieve(img7,  "대천보령패러글라이딩.jpg")
urllib.request.urlretrieve(img8,  "하늘물빛정원.jpg")
urllib.request.urlretrieve(img9,  "당진삽교호카트월드.jpg")
urllib.request.urlretrieve(img10,  "대천카트.jpg")
urllib.request.urlretrieve(img11,  "안면카트체험장.jpg")
urllib.request.urlretrieve(img12,  "스카이바이크.jpg")
urllib.request.urlretrieve(img13,  "대천레일바이크.jpg")
urllib.request.urlretrieve(img14,  "아산레일바이크.jpg")



import pandas as pd
import bson
import io
import base64

data = [
            {"지역" : "금산", "이름" : "대둔산짚핑", "카테고리": "짚라인", "주소": "충청남도 금산군 지난면 대둔산로 8-1", "좌표(x)": 36.12595338318075, "좌표(y)": 127.34115669459696, "전화": "1644-8713", "요금" : "하계코스 55,000원"}, 
            {"지역" : "보령", "이름" : "대천짚라인", "카테고리": "짚라인", "주소": "충청남도 보령시 해수욕장 10길 80", "좌표(x)": 36.321633094635466, "좌표(y)": 126.50665542720368, "전화": "041-934-3003", "요금" : "18,000원"}, 
            {"지역" : "아산", "이름" : "영인산자연휴양림", "카테고리": "짚라인", "주소": "충청남도 아산시 영인면 아산온천로 16-26" , "좌표(x)": 36.84036207096012, "좌표(y)": 126.95137459095396, "전화": "041-538-1959", "요금" : "10,000원"}, 
            
            {"지역" : "논산",  "이름": "강경수상레저", "카테고리": "수상스포츠", "주소": "충청남도 논산시 강경읍 황산리 27-8", "좌표(x)": 36.158093666290306, "좌표(y)": 127.01056769769707, "전화": "041-745-5200", "요금" : "웨이크보드 체험 30,000원"}, 
            {"지역" : "보령",  "이름": "해양레저체험교실", "카테고리": "수상스포츠", "주소": "충청남도 보령시 남포면 열린바다로 65", "좌표(x)": 36.260611788387074, "좌표(y)": 126.54673039770005, "전화": "1688-3936", "요금" : "플라이보드 60,000원"},  
            {"지역" : "천안",  "이름": "천안케이블워터파크", "카테고리": "수상스포츠", "주소": "충청남도 천안시 동남구 문암로 227", "좌표(x)": 36.84120024687879, "좌표(y)": 127.18183929596863, "전화": "041-522-3323", "요금" : "주말 1시간 40,000원"}, 
            
            {"지역" : "보령",  "이름": "대천패러글라이딩", "카테고리": "페러글라이딩", "주소": "충청남도 보령시 명천동 938", "좌표(x)": 36.32592998763038, "좌표(y)": 126.60966826886614, "전화": "010-3045-2389", "요금" : "주말 일반코스 80,000원"}, 
            {"지역" : "보령",  "이름": "대천보령패러글라이딩", "카테고리": "페러글라이딩", "주소": "충청남도 보령시 남포면 창동리 205-1", "좌표(x)": 36.32061433517254, "좌표(y)": 126.6134684111943, "전화": "010-2488-4129", "요금" : "주말 일반코스 80,000원"}, 
           
            {"지역" : "금산",  "이름": "하늘물빛정원", "카테고리": "카트", "주소": "충청남도 금산군 추부면 검한1길 156", "좌표(x)": 36.225047829856834, "좌표(y)": 127.48385092655256, "전화": "1588-2613", "요금" : " 7바퀴 10,000원"}, 
            {"지역" : "당진",  "이름": "당진삽교호카트월드", "카테고리": "카트", "주소": "충청남도 당진시 신평면 삽교천길 71", "좌표(x)": 36.886267442211974, "좌표(y)": 126.8227612977359, "전화": "041-363-6647", "요금" : "약 10분 15,000원"}, 
            {"지역" : "보령",  "이름": "대천카트", "카테고리": "카트", "주소": "충청남도 보령시 해수욕장10길 80", "좌표(x)": 36.3213627628151, "좌표(y)": 126.50724575510377, "전화": " 041-935-8787", "요금" : "약 10분 20,000원"}, 
            {"지역" : "태안",  "이름": "안면카트체험장", "카테고리": "카트", "주소": "충청남도 태안군 안면읍 백사장1길 59", "좌표(x)": 36.58297764721912, "좌표(y)": 126.31973055539868, "전화": "041-675-1003", "요금" : "약 20분 20,000원"}, 
            
            {"지역" : "보령",  "이름": "스카이바이크", "카테고리": "레일바이크", "주소": "충청남도 보령시 해수욕장10길 79", "좌표(x)": 36.31873242535947, "좌표(y)": 126.50833090539105, "전화": "041-931-1180", "요금" : "2인 22,000원 / 4인 30,000원"}, 
            {"지역" : "보령",  "이름": "대천레일바이크", "카테고리": "레일바이크", "주소": "충청남도 보령시 옥마벚길 10", "좌표(x)": 36.33210874057714, "좌표(y)": 126.62300199771995, "전화": "041-939-3600", "요금" : "1인 20,000원 / 4인 26,000원"}, 
            {"지역" : "아산",  "이름": "아산레일바이크", "카테고리": "레일바이크", "주소": "충청남도 아산시 도고면 아산만로 199-7", "좌표(x)": 36.761344332499434, "좌표(y)": 126.86723079773233, "전화": "041-547-7882", "요금" : "2인승 25,000원 / 4인 : 33,000원"}  
           ]

df = pd.DataFrame(data)
df

import pymongo
import bson

try:
    username = "id119"
    password = "pw119"
    host = "1.234.5.158"
    port = 37017
    dbname = "id119"

    conn= pymongo.MongoClient(f'mongodb://{username}:{password}@{host}:{port}/{dbname}')
    db = conn.get_database(dbname) #db선택
    collection = db.get_collection("엑티비티")
    

except Exception as e:
    print(e)
finally:
    conn.close()

for data in df.values:
#     print(data[0])
    path = f'{data[1]}.jpg'
    img = Image.open(path)
    img = img.resize((250, 250))
    img.save(f'{data[1]}.jpg')
    with open(path, 'rb') as f:
        pic1 = f.read()
    pic1 = io.BytesIO(pic1)
    
    pic = base64.b64encode(open(f'{data[1]}.jpg', 'rb').read()).decode()
    
    arr = [{
        "지역":data[0],
        "이름":data[1],
        "카테고리":data[2],
        "주소":data[3],
        "좌표(x)":data[4],
        "좌표(y)":data[5],
        "전화":data[6],
        "요금":data[7],
        "이미지":bson.Binary(pic1.read())
    }]
    
    collection.insert_many(arr)
    
    
# data5 = [] # mongodb에 추가하기 위한 [{}, {}, {}] 로 저장하기 위한 변수
# for tmp in data1:
#     response = requests.get(tmp) # src 주소를 호출해서 값을 받아옴
#     byte1 = io.BytesIO(response.content) # 받아온 값을 bytes로 변경
#     data5.append(bson.Binary(byte1.read()) )

# %%
import requests
import hdfs 
import json
import bs4

try:
    username = "id119"
    password = "pw119"
    host = "1.234.5.158"
    port = 37017
    dbname = "id119"

    conn= pymongo.MongoClient(f'mongodb://{username}:{password}@{host}:{port}/{dbname}')
    db = conn.get_database(dbname) #db선택
    collection = db.get_collection("엑티비티")
    
    # 수집한 데이터 [ {}, {}, {} ] => mongodb, hadoop 
    data = [{"지역" : "금산", "이름" : "대둔산짚핑", "카테고리": "짚라인", "주소": "충청남도 금산군 지난면 대둔산로 8-1", "좌표(x)": 36.12595338318075, "좌표(y)": 127.34115669459696, "전화": "1644-8713", "요금" : "하계코스 55,000원", "image": data5[0]}, 
            {"지역" : "보령", "이름" : "대천짚라인", "카테고리": "짚라인", "주소": "충청남도 보령시 해수욕장 10길 80", "좌표(x)": 36.321633094635466, "좌표(y)": 126.50665542720368, "전화": "041-934-3003", "요금" : "18,000원", "image": data5[2]}, 
            {"지역" : "아산", "이름" : "영인산자연휴양림", "카테고리": "짚라인", "주소": "충청남도 아산시 영인면 아산온천로 16-26" , "좌표(x)": 36.84036207096012, "좌표(y)": 126.95137459095396, "전화": "041-538-1959", "요금" : "10,000원", "image": data5[1]}, 
            
            {"지역" : "논산",  "이름": "강경수상레저", "카테고리": "수상스포츠", "주소": "충청남도 논산시 강경읍 황산리 27-8", "좌표(x)": 36.158093666290306, "좌표(y)": 127.01056769769707, "전화": "041-745-5200", "요금" : "웨이크보드 체험 30,000원", "image": data5[3]}, 
            {"지역" : "보령",  "이름": "해양레저체험교실", "카테고리": "수상스포츠", "주소": "충청남도 보령시 남포면 열린바다로 65", "좌표(x)": 36.260611788387074, "좌표(y)": 126.54673039770005, "전화": "1688-3936", "요금" : "플라이보드 60,000원", "image": data5[4]},  
            {"지역" : "천안",  "이름": "천안케이블워터파크", "카테고리": "수상스포츠", "주소": "충청남도 천안시 동남구 문암로 227", "좌표(x)": 36.84120024687879, "좌표(y)": 127.18183929596863, "전화": "041-522-3323", "요금" : "주말 1시간 40,000원", "image": data5[5]}, 
            
            {"지역" : "보령",  "이름": "대천패러글라이딩", "카테고리": "페러글라이딩", "주소": "충청남도 보령시 명천동 938", "좌표(x)": 36.32592998763038, "좌표(y)": 126.60966826886614, "전화": "010-3045-2389", "요금" : "주말 일반코스 80,000원", "image": data5[6]}, 
            {"지역" : "보령",  "이름": "대천보령패러글라이딩", "카테고리": "페러글라이딩", "주소": "충청남도 보령시 남포면 창동리 205-1", "좌표(x)": 36.32061433517254, "좌표(y)": 126.6134684111943, "전화": "010-2488-4129", "요금" : "주말 일반코스 80,000원", "image": data5[7]}, 
           
            {"지역" : "금산",  "이름": "하늘물빛정원", "카테고리": "카트", "주소": "충청남도 금산군 추부면 검한1길 156", "좌표(x)": 36.225047829856834, "좌표(y)": 127.48385092655256, "전화": "1588-2613", "요금" : " 7바퀴 10,000원", "image": data5[8]}, 
            {"지역" : "당진",  "이름": "당진삽교호카트월드", "카테고리": "카트", "주소": "충청남도 당진시 신평면 삽교천길 71", "좌표(x)": 36.886267442211974, "좌표(y)": 126.8227612977359, "전화": "041-363-6647", "요금" : "약 10분 15,000원", "image": data5[9]}, 
            {"지역" : "보령",  "이름": "대천카트", "카테고리": "카트", "주소": "충청남도 보령시 해수욕장10길 80", "좌표(x)": 36.3213627628151, "좌표(y)": 126.50724575510377, "전화": " 041-935-8787", "요금" : "약 10분 20,000원", "image": data5[10]}, 
            {"지역" : "태안",  "이름": "안면카트체험장", "카테고리": "카트", "주소": "충청남도 태안군 안면읍 백사장1길 59", "좌표(x)": 36.58297764721912, "좌표(y)": 126.31973055539868, "전화": "041-675-1003", "요금" : "약 20분 20,000원", "image": data5[11]}, 
            
            {"지역" : "보령",  "이름": "스카이바이크", "카테고리": "레일바이크", "주소": "충청남도 보령시 해수욕장10길 79", "좌표(x)": 36.31873242535947, "좌표(y)": 126.50833090539105, "전화": "041-931-1180", "요금" : "2인 22,000원 / 4인 30,000원", "image": data5[12]}, 
            {"지역" : "보령",  "이름": "대천레일바이크", "카테고리": "레일바이크", "주소": "충청남도 보령시 옥마벚길 10", "좌표(x)": 36.33210874057714, "좌표(y)": 126.62300199771995, "전화": "041-939-3600", "요금" : "1인 20,000원 / 4인 26,000원", "image": data5[13]}, 
            {"지역" : "아산",  "이름": "아산레일바이크", "카테고리": "레일바이크", "주소": "충청남도 아산시 도고면 아산만로 199-7", "좌표(x)": 36.761344332499434, "좌표(y)": 126.86723079773233, "전화": "041-547-7882", "요금" : "2인승 25,000원 / 4인 : 33,000원", "image": data5[14]},             
           ]
    collection.insert_many(data)
    
except Exception as e:
    print(e)
finally:
    conn.close()

# %%
import requests
import hdfs 
import json
import bs4

try:
    username = "id119"
    password = "pw119"
    host = "1.234.5.158"
    port = 37017
    dbname = "id119"

    conn= pymongo.MongoClient(f'mongodb://{username}:{password}@{host}:{port}/{dbname}')
    db = conn.get_database(dbname) #db선택
    collection = db.get_collection("레저")
    
    # 수집한 데이터 [ {}, {}, {} ] => mongodb, hadoop 
    data = [{ "이름" : "레저카라반", "주소": "충청남도 천안시 서북구 성환읍 성월리 234-1", "좌표(x)": 36.95449849149154, "좌표(y)": 127.14653535641281, "전화": "041-565-1029",  "image": data5[0]}, 
            { "이름" : "상록골프&레저", "주소": "충청남도 천안시 동남구 수신면 수신로 576", "좌표(x)": 36.75890828650242, "좌표(y)": 127.2866110362893, "전화": "041-560-9114",  "image": data5[1]}, 
            { "이름" : "공주청벽수상레저", "주소": "충청남도 공주시 반포면 마암리 709", "좌표(x)": 36.448017473802516, "좌표(y)": 127.21245332487125, "전화": "041-856-0108",  "image": data5[2]}, 
            { "이름" : "금강아쿠아레져", "주소": "충청남도 금산군 제원면 천내리 243-6", "좌표(x)": 36.13143924801076, "좌표(y)": 127.58873506621376, "전화": "041-753-2555",  "image": data5[3]}, 
            { "이름" : "심천레저리조트캠핑장/루프탑글램핑", "주소": "충청남도 금산군 남일면 신동리 692", "좌표(x)": 36.007114937019104, "좌표(y)": 127.48436495179595, "전화": "010-5432-1335",  "image": data5[4]}, 
            { "이름" : "백마강레저파크", "주소": "충청남도 부여군 규암면 호암리 234-2", "좌표(x)": 36.3175569505387,  "좌표(y)": 126.91856905007855, "전화": "1833-8982",  "image": data5[5]}, 
            { "이름" : "안면도레포츠월드", "주소": "충청남도 태안군 안면읍 중장리 1586-5", "좌표(x)": 36.48772734320616, "좌표(y)": 126.35999225079317, "전화": "041-674-5482",  "image": data5[6]}, 
            { "이름" : "삼원레저타운캠핑장", "주소": "충청남도 서산시 팔봉면 진장서낭골길 204", "좌표(x)": 36.78214704957507,  "좌표(y)": 126.35139986416493, "전화": "041-663-1111",  "image": data5[7]}, 
            { "이름" : "으랏차차좌대낚시", "주소": "충청남도 서산시 부석면 창리2길 62", "좌표(x)": 36.62487044311896, "좌표(y)": 126.36748439772835, "전화": "010-9491-9293",  "image": data5[8]}, 
            
            { "이름" : "용궁좌대낚시", "주소": "충청남도 태안군 고남면 누동리 1505-5", "좌표(x)": 36.43591868002538, "좌표(y)": 126.43159239772292, "전화": "041-675-7500",  "image": data5[9]}, 
            { "이름" : "금강수상레저", "주소": "충청남도 부여군 양화면 유왕로 210 금강수상레저", "좌표(x)": 36.12259754528939, "좌표(y)": 126.87457565538553, "전화": "0507-1496-3444",  "image": data5[10]}, 
            { "이름" : "공주경비행기", "주소": "충청남도 공주시 의당면 수촌리 943", "좌표(x)": 36.51051134984575,  "좌표(y)": 127.12577539772504, "전화": "0507-1380-8226",  "image": data5[11]}, 
            { "이름" : "신정호뉴수상스키장", "주소": "충청남도 아산시 방축동  467-20", "좌표(x)": 36.77336636776001,  "좌표(y)": 126.98187959773257, "전화": "041-548-1128",  "image": data5[12]}
                  
           ]
    collection.insert_many(data)
    
except Exception as e:
    print(e)
finally:
    conn.close()

# %%
import requests
import hdfs 
import json
import bs4
import requests
import io
import bson
import time
from selenium import webdriver  # pip install selenium
import bs4 # pip install bs4
import time
import urllib.request as REQ  #서버 요청
import pymongo

img = "https://mblogthumb-phinf.pstatic.net/MjAxNzA2MDdfMjA1/MDAxNDk2Nzk3MzA5MTE0.V-DKCkilx0Gt54a-y7es-3N8ZnHCiu0sf7RBT7uqYKkg.-yZfMgwhdPAiF166IrqgLGeM-Bx83e2rx5TkUmyXQxog.JPEG.buyeoblog/01.jpg?type=w800"
img1 = "https://m.ktcu.or.kr/resources/smart/img/thumb/img_member_10.jpg"
img2 = "http://www.gongju.go.kr/thumbnail/tursmCn/920_TUCN_202004270402326134.jpg"

img3 = "https://search.pstatic.net/common/?autoRotate=true&quality=100&type=f640_380&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20150831_127%2F1441000390247iomot_JPEG%2F12015012_0.jpg"
img4 = "https://img1.daumcdn.net/thumb/R720x0.q80/?scode=mtistory2&fname=http%3A%2F%2Fcfile10.uf.tistory.com%2Fimage%2F99E3303F5B31B7FC25F1CD"
img5 = "https://img1.daumcdn.net/thumb/R720x0.q80/?scode=mtistory2&fname=http%3A%2F%2Fcfile24.uf.tistory.com%2Fimage%2F999909385B42DEA20FF1CB"

img6 = "https://mblogthumb-phinf.pstatic.net/MjAxODA2MjVfMjc1/MDAxNTI5OTMwOTEyODk1.vHQpBXt0IHzEbfjBcR_NCEcuHxsA1SLXi1cmnkGMdZkg.6mMCdzJydG7GoEIah0yjUgkzBQRL6FPYSJ-QKTKvSKQg.JPEG.hp0210/077-20180624.JPG?type=w800"
img7 = "https://lh3.googleusercontent.com/proxy/vTWrDsx9Xo6iW1wiBdCjU85TlkpIFrnj4wLf_yo7DyKHy-81UCN0Qlrr1n_n7DbwIvvmZrYuiaMfjIvdESly02pq_WyXMArXP1kX0sMKjcZwoPp_yd1ftgDMquFk1z2z-UiLXKJmFGWqIGZLx73xiLOuksfVag"

img8 = "https://t1.daumcdn.net/cfile/blog/251ED74F551CAFBA09"
img9 = "https://mblogthumb-phinf.pstatic.net/20141004_56/hanjun66_1412429002236TUbap_JPEG/IMG_7467.JPG?type=w2"
img10 = "https://lh3.googleusercontent.com/proxy/C2qC4qjf_0xNfAbTnDo4A0YB-aMeayTFj4L5mX7_PIMomPtsMWYZiLK-baKN4Tu-pltSAL1qfMoXjWVdR1Nzm-RJfXWCTJq06np4yDcpAT9x4_HYfarhn0jz3mQzck4iaZldR9GuHSjiP1zSlRrjIdhK"
img11 = "http://www.gongju.go.kr/thumbnail/tursmCn/920_TUCN_202004270405532433.jpg"

img12 = "https://i.ytimg.com/vi/_xrM_HzO0T4/maxresdefault.jpg"



data1 = []
data1.append(img)
data1.append(img1)
data1.append(img2)
data1.append(img3)
data1.append(img4)
data1.append(img5)
data1.append(img6)
data1.append(img7)
data1.append(img8)
data1.append(img9)
data1.append(img10)
data1.append(img11)
data1.append(img12)


# data5 = [] # mongodb에 추가하기 위한 [{}, {}, {}] 로 저장하기 위한 변수
# for tmp in data1:
#     response = requests.get(tmp) # src 주소를 호출해서 값을 받아옴
#     byte1 = io.BytesIO(response.content) # 받아온 값을 bytes로 변경
#     data5.append(bson.Binary(byte1.read()) )

# %%
import folium
help(folium.Icon)
# Out:
# Help on class Icon in module folium.map:
#
# class Icon(branca.element.MacroElement)
#  |  Icon(color='blue', icon_color='white', icon='info-sign', angle=0, prefix='glyphicon', **kwargs)
#  |
#  |  Creates an Icon object that will be rendered
#  |  using Leaflet.awesome-markers.
#  |
#  |  Parameters
#  |  ----------
#  |  color : str, default 'blue'
#  |      The color of the marker. You can use:
#  |
#  |          ['red', 'blue', 'green', 'purple', 'orange', 'darkred',
#  |           'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue',
#  |           'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen',
#  |           'gray', 'black', 'lightgray']
#  |
#  |  icon_color : str, default 'white'
#  |      The color of the drawing on the marker. You can use colors above,
#  |      or an html color code.
#  |  icon : str, default 'info-sign'
#  |      The name of the marker sign.
#  |      See Font-Awesome website to choose yours.
# ...

# %%
# db 연결
import pymongo
import requests
import folium
from bs4 import BeautifulSoup
from folium.plugins import MarkerCluster
import pandas as pd
import bs4
import requests
import json
import hdfs
import os
import csv
from folium import plugins
import json
import urllib.request
from pandas import DataFrame, Series
from urllib.request import urlopen
import matplotlib.pyplot as plt
import base64
from folium import FeatureGroup, LayerControl, Map, Marker
from hdfs import InsecureClient
import pandas as pd
import bson
import io
from PIL import Image


try:
    username = "id119"
    password = "pw119"
    host = "1.234.5.158"
    port = 37017
    dbname = "id119"
    
    conn = pymongo.MongoClient(f'mongodb://{username}:{password}@{host}:{port}/{dbname}')
    db = conn.get_database(dbname)
    collection = db.get_collection("p_tourmap")
    collection1 = db.get_collection("p_lodgmap")
    collection3 = db.get_collection("음식점전체정보")    
    collection4 = db.get_collection("Map")
    collection5 = db.get_collection("User")
    collection6 = db.get_collection("관광명소")
    collection7 = db.get_collection("숙박업소")
    collection8 = db.get_collection("음식점")

except Exception as e:
    print(e)
finally:
    conn.close()
